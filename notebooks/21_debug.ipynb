# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import importlib
import pandas as pd
import numpy as np
import importlib

sys.path.append(os.path.abspath(".."))

import src.models.mlp.keep_trying as cv
import src.utils.optuna_visualizer as opv
import src.utils.telegram as te

# %%
# Load data
env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=env_path)
url = os.environ.get("OPTUNA_STORAGE_URL")

test_df20 = pd.read_parquet("../artifacts/features/base/test_df20.parquet")
tr_df20 = pd.read_parquet("../artifacts/features/base/tr_df20.parquet")

# %%
# Create OOF and test predictions
importlib.reload(cv)
tr_df20 = tr_df20[:30000]
params = {
    "num_layers": 3,
    "hidden_dim1": 352,
    "hidden_dim2": 256,
    "hidden_dim3": 224,
    "hidden_dim4": 128,
    "batch_size": 896,
    "lr": 0.016867490361457304,
    "eta_min": 3.9793716038378347e-05,
    "dropout_rate": 0.35,
    "activation": "GELU",
    "min_epochs": 10,
    "early_stopping_rounds": 10
}
trainer = cv.MLPCVTrainer(tr_df20, test_df=test_df20, params=params)
trainer.fit()
# Out:
# Fold 1
# Epoch 1: Train Logloss = 0.24038, Val Logloss = 0.24998
# New best model saved at epoch 1, Logloss: 0.24998
# Epoch 2: Train Logloss = 0.14780, Val Logloss = 0.15147
# New best model saved at epoch 2, Logloss: 0.15147
# Epoch 3: Train Logloss = 0.14387, Val Logloss = 0.14957
# New best model saved at epoch 3, Logloss: 0.14957
# Epoch 4: Train Logloss = 0.14492, Val Logloss = 0.14526
# New best model saved at epoch 4, Logloss: 0.14526
# Epoch 5: Train Logloss = 0.13872, Val Logloss = 0.14642
# Epoch 6: Train Logloss = 0.13524, Val Logloss = 0.14372
# New best model saved at epoch 6, Logloss: 0.14372
# Epoch 7: Train Logloss = 0.13379, Val Logloss = 0.14657
# Epoch 8: Train Logloss = 0.13305, Val Logloss = 0.14520
# Epoch 9: Train Logloss = 0.13580, Val Logloss = 0.15181
# Epoch 10: Train Logloss = 0.13243, Val Logloss = 0.14559
# Epoch 11: Train Logloss = 0.12594, Val Logloss = 0.14642
# Epoch 12: Train Logloss = 0.12652, Val Logloss = 0.14815
# ...
