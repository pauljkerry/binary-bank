# %%
import os
import json
from datetime import datetime
from pathlib import Path

import wandb
from dotenv import load_dotenv
import numpy as np
import polars as pl
from kaggle.api.kaggle_api_extended import KaggleApi
from kagglesdk.competitions.types.competition_api_service import SubmissionGroup

# %% [markdown]
# # Config

# %%
load_dotenv(dotenv_path="../.env")
wandb.login(key=os.environ.get("WANDB_API_KEY"))

RUN_ID = "xgb-023-trl44-s42"
MESSAGE = "Good Luck!"
COMP = os.environ.get("COMPETITION_NAME")

RUNS = Path("../runs") / RUN_ID
OUTPUT = Path("../output")
INPUT = Path("../input")

MANIFEST_PATH = RUNS / "manifest.json"
SUB_PATH = OUTPUT / f"{RUN_ID}.csv"

api = KaggleApi()
api.authenticate()

with open(MANIFEST_PATH) as f:
    m = json.load(f)

WANDB_ID = m["wandb_id"]
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/hanse/.netrc
# wandb: Currently logged in as: kaitookano (kaitookano-waseda-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# # Submit

# %%
test = np.load(RUNS / "test.npy")[:250000]

sample_sub = pl.read_csv(INPUT / "sample_submission.csv")

if len(sample_sub) != len(test):
    raise ValueError(
        f"Row mismatch: sample={len(sample_sub)}, test={len(test)}"
    )

sub = sample_sub.with_columns(
    pl.Series("y", test)
)
sub.write_csv(SUB_PATH)

result = api.competition_submit(
    file_name=SUB_PATH,
    message=MESSAGE,
    competition=COMP
)

ref = result.ref

submitted_at = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Ref: {ref}")

# %% [markdown]
# # Public Score

# %%
# === Check Public Score ===
subs = api.competition_submissions(
    COMP,
    group=SubmissionGroup.SUBMISSION_GROUP_SUCCESSFUL  # ← 実際に print で確認した正しい名前を指定
)

target = next((s for s in subs if s.ref == ref), None)

public = target.public_score
date = target.date

if target:
    print(
        f"Public LB: {public}"
        f"Date: {date}"
    )
else:
    print("Subs not found")
# Out:
# Public LB: 0.97696Date: 2025-09-20 00:32:48

# %%
# === Record Public Score in WandB===
run = wandb.init(
    project=COMP,
    id=WANDB_ID,
    resume="must"   # ← 既存 run を再開
)
run.log({"public": public})

run.config.update({"ref": ref})

run.finish()
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/hanse/kaggle/binary-bank/notebooks/wandb/run-20250920_093417-ukv0fjm8</code>
# Resuming run <strong><a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8' target="_blank">trl44</a></strong> to <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8</a>
#  View run at <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>auc_f1</td><td>0.97669</td></tr><tr><td>auc_f2</td><td>0.97585</td></tr><tr><td>auc_f3</td><td>0.97517</td></tr><tr><td>auc_f4</td><td>0.97641</td></tr><tr><td>auc_f5</td><td>0.97587</td></tr><tr><td>auc_mean</td><td>0.976</td></tr><tr><td>auc_oof</td><td>0.97599</td></tr><tr><td>auc_std</td><td>0.00052</td></tr><tr><td>best_iter_f1</td><td>1845</td></tr><tr><td>best_iter_f2</td><td>1470</td></tr><tr><td>best_iter_f3</td><td>1867</td></tr><tr><td>best_iter_f4</td><td>2001</td></tr><tr><td>best_iter_f5</td><td>1765</td></tr><tr><td>eval/auc_f1</td><td>0.97667</td></tr><tr><td>eval/auc_f2</td><td>0.97581</td></tr><tr><td>eval/auc_f3</td><td>0.97516</td></tr><tr><td>eval/auc_f4</td><td>0.97636</td></tr><tr><td>eval/auc_f5</td><td>0.97583</td></tr><tr><td>iter</td><td>2265</td></tr><tr><td>iter_mean</td><td>1789.6</td></tr><tr><td>public</td><td>0.97696</td></tr><tr><td>train/auc_f1</td><td>0.99642</td></tr><tr><td>train/auc_f2</td><td>0.99512</td></tr><tr><td>train/auc_f3</td><td>0.99659</td></tr><tr><td>train/auc_f4</td><td>0.9969</td></tr><tr><td>train/auc_f5</td><td>0.99618</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">trl44</strong> at: <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8</a><br> View project at: <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250920_093417-ukv0fjm8/logs</code>

# %%
# === Update Manifest ===
m["submission"]["ref"] = ref
m["submission"]["file"] = str(SUB_PATH)
m["submission"]["competition"] = COMP
m["submission"]["public_score"] = public
m["submission"]["submitted_at"] = submitted_at

with open(MANIFEST_PATH, "w") as f:
    json.dump(m, f, indent=4)

# %% [markdown]
# # Private Score

# %%
subs = api.competition_submissions(
    COMP,
    group=SubmissionGroup.SUBMISSION_GROUP_SUCCESSFUL
)

target = next((s for s in subs if s.ref == ref), None)

private = target.private_score

if target:
    print(f"Private LB: {private}")
else:
    print("Subs not found")
# Out:
# Private LB: 0.97661

# %%
# === Record Private Score in WandB===
run = wandb.init(
    project=COMP,
    id=WANDB_ID,
    resume="must"
)
run.log({"private": private})

run.finish()
# Out:
# Tracking run with wandb version 0.21.1
# Run data is saved locally in <code>/home/hanse/kaggle/binary-bank/notebooks/wandb/run-20250920_093608-ukv0fjm8</code>
# Resuming run <strong><a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8' target="_blank">trl44</a></strong> to <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8</a>
#  View run at <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>auc_f1</td><td>0.97669</td></tr><tr><td>auc_f2</td><td>0.97585</td></tr><tr><td>auc_f3</td><td>0.97517</td></tr><tr><td>auc_f4</td><td>0.97641</td></tr><tr><td>auc_f5</td><td>0.97587</td></tr><tr><td>auc_mean</td><td>0.976</td></tr><tr><td>auc_oof</td><td>0.97599</td></tr><tr><td>auc_std</td><td>0.00052</td></tr><tr><td>best_iter_f1</td><td>1845</td></tr><tr><td>best_iter_f2</td><td>1470</td></tr><tr><td>best_iter_f3</td><td>1867</td></tr><tr><td>best_iter_f4</td><td>2001</td></tr><tr><td>best_iter_f5</td><td>1765</td></tr><tr><td>eval/auc_f1</td><td>0.97667</td></tr><tr><td>eval/auc_f2</td><td>0.97581</td></tr><tr><td>eval/auc_f3</td><td>0.97516</td></tr><tr><td>eval/auc_f4</td><td>0.97636</td></tr><tr><td>eval/auc_f5</td><td>0.97583</td></tr><tr><td>iter</td><td>2265</td></tr><tr><td>iter_mean</td><td>1789.6</td></tr><tr><td>private</td><td>0.97661</td></tr><tr><td>public</td><td>0.97696</td></tr><tr><td>train/auc_f1</td><td>0.99642</td></tr><tr><td>train/auc_f2</td><td>0.99512</td></tr><tr><td>train/auc_f3</td><td>0.99659</td></tr><tr><td>train/auc_f4</td><td>0.9969</td></tr><tr><td>train/auc_f5</td><td>0.99618</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">trl44</strong> at: <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8/runs/ukv0fjm8</a><br> View project at: <a href='https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8' target="_blank">https://wandb.ai/kaitookano-waseda-university/playground-series-s5e8</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250920_093608-ukv0fjm8/logs</code>

# %%
# === Update Manifest ===
m["submission"]["private_score"] = private
with open(MANIFEST_PATH, "w") as f:
    json.dump(m, f, indent=4)
