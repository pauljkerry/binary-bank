# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv
import pandas as pd
import optuna

sys.path.append(os.path.abspath(".."))


from src.utils.get_objective import get_objective
import src.utils.run_optuna as op

# %%
# Load data
env_path = Path.cwd().parent / ".env"
load_dotenv(dotenv_path=env_path)
url = os.environ.get("OPTUNA_STORAGE_URL")

model_name = "lgbm"
create_objective = get_objective(model_name)

tr_df = pd.read_parquet("../artifacts/features/base/tr_df23.parquet")

# %%
# Tuning
objective = create_objective(
    tr_df,
    early_stopping_rounds=200,
    n_jobs=10
)
op.run_optuna_search(
    objective,
    n_trials=20,
    n_jobs=1,
    direction="maximize",
    study_name=f"{model_name}_v3",
    storage=url,
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=15, seed=42)
)
# Out:
# [I 2025-08-29 02:48:05,002] A new study created in RDB with name: lgbm_v3
#   0%|          | 0/20 [00:00<?, ?it/s]
# Training until validation scores don't improve for 200 rounds
# [100]	train's auc: 0.967544	eval's auc: 0.968237
# [200]	train's auc: 0.97038	eval's auc: 0.970857
# [300]	train's auc: 0.972175	eval's auc: 0.972532
# [400]	train's auc: 0.973492	eval's auc: 0.973683
# [500]	train's auc: 0.974334	eval's auc: 0.974342
# [600]	train's auc: 0.974929	eval's auc: 0.97473
# [700]	train's auc: 0.975429	eval's auc: 0.975038
# [800]	train's auc: 0.975845	eval's auc: 0.975256
# [900]	train's auc: 0.976229	eval's auc: 0.975431
# [1000]	train's auc: 0.976556	eval's auc: 0.97556
# [1100]	train's auc: 0.976871	eval's auc: 0.975674
# [1200]	train's auc: 0.977158	eval's auc: 0.975774
# [1300]	train's auc: 0.977423	eval's auc: 0.975852
# [1400]	train's auc: 0.977666	eval's auc: 0.975929
# [1500]	train's auc: 0.977916	eval's auc: 0.975996
# ...
